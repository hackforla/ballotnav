# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Scrape-Wyoming---County-Officials" data-toc-modified-id="Scrape-Wyoming---County-Officials-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Scrape Wyoming - County Officials</a></span><ul class="toc-item"><li><span><a href="#fitz-needs-the-pdf-file-to-be-located-locally." data-toc-modified-id="fitz-needs-the-pdf-file-to-be-located-locally.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>fitz needs the pdf file to be located locally.</a></span></li></ul></li><li><span><a href="#Analyze-the-format-of-the-text" data-toc-modified-id="Analyze-the-format-of-the-text-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Analyze the format of the text</a></span></li><li><span><a href="#Extract-the-a-list-of-the-county-clerks'-names" data-toc-modified-id="Extract-the-a-list-of-the-county-clerks'-names-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Extract the a list of the county clerks' names</a></span></li><li><span><a href="#Break-counties-into-two-groups,-those-in-the-left-column-and-those-in-the-right" data-toc-modified-id="Break-counties-into-two-groups,-those-in-the-left-column-and-those-in-the-right-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Break counties into two groups, those in the left column and those in the right</a></span></li><li><span><a href="#Loop-through-the-left-column-of-addresses-to-build-a-dict" data-toc-modified-id="Loop-through-the-left-column-of-addresses-to-build-a-dict-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Loop through the left column of addresses to build a dict</a></span></li><li><span><a href="#Loop-through-the-right-column-of-address-to-build-a-dict" data-toc-modified-id="Loop-through-the-right-column-of-address-to-build-a-dict-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Loop through the right column of address to build a dict</a></span></li><li><span><a href="#Create-DataFrame-of-data" data-toc-modified-id="Create-DataFrame-of-data-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Create DataFrame of data</a></span></li><li><span><a href="#Remove-email-tag-from-field" data-toc-modified-id="Remove-email-tag-from-field-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Remove email tag from field</a></span></li><li><span><a href="#Write-DataFrame-to-csv" data-toc-modified-id="Write-DataFrame-to-csv-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Write DataFrame to csv</a></span></li></ul></div>

# %% [markdown]
# # Scrape Wyoming - County Officials

# %%
import fitz
import numpy as np
import pandas as pd
import re

# %%
# verify installation
print(fitz.__doc__)
# Out:
# PyMuPDF 1.17.6: Python bindings for the MuPDF 1.17.0 library.
# Version date: 2020-08-26 14:54:32.
# Built for Python 3.6 on darwin (64-bit).

# %% [markdown]
# ## fitz needs the pdf file to be located locally.
#
# Downloaded from this url: https://sos.wyo.gov/Elections/Docs/WYCountyClerks_AbsRequest_VRChange.pdf

# %%
path = ".../ballot_nav/WYCountyClerks_AbsRequest_VRChange.pdf"
doc = fitz.open(path)

# %%
raw_text = ""
for page in doc:
    text = page.getText("text")
    raw_text += text

# %%
type(raw_text)
# Out:
# str

# %%
raw_text
# Out:
# 'Wyoming County Clerk’s Office \nAbsentee Request and Updates to Voter Registration \nContact Information \n \n \n \n \n \n \nPage 1 of 3 \nAlbany County Clerk \nBig Horn County Clerk \n525 Grand Avenue, Suite 202 \nLaramie, WY 82070 \nPh. 307.721.2546 \nFax 307.721.2544 \nEmail: elections@co.albany.wy.us \nCounty Courthouse, P.O. Box 31 \nBasin, WY 82410-0031 \nPh. 307.568.2357 \nFax 307.568.9375 \nEmail: Lori.Smallwood@bighorncountywy.gov \n          annette.dillon@bighorncountywy.gov \nCampbell County Clerk \nCarbon County Clerk \nP.O. Box 3010 \nGillette, WY 82717-3010 \nPh. 307.686.1892 \nFax 307.687.6455 \nEmail: cds02@ccgov.net \nP.O. Box 6 \nRawlins, WY 82301-0006 \nPh. 307.328.2650 \nFax 307.328.2669 \nEmail: elections@carbonwy.com     \nConverse County Clerk \nCrook County Clerk \n107 North 5th Street, Suite 114 \nDouglas, WY 82633-2448 \nPh. 307.358.2244 \nFax 307.358.5998 \nEmail:janeen.morvee@conversecountywy.gov \n            \nP.O. Box 37 \nSundance, WY 82729-0037 \nPh. 307.283.1323 \nFax 307.283.3038 \nEmail: LindaF@crookcounty.wy.gov \n               melissaj@crookcounty.wy.gov \nFremont County Clerk \nGoshen County Clerk \n450 North 2nd Street, Room 220 \nLander, WY 82520-0090 \nPh. 307.332.1089 \nFax 307.332.1132 \nEmail: elections@fremontcountywy.gov \nP.O. Box 160 \nTorrington, WY 82240-0160 \nPh. 307.532.4051 \nFax 307.532.7375 \nEmail: countyclerk@goshencounty.org \n \nPage 2 of 3 \n \nHot Springs County Clerk \nJohnson County Clerk \n415 Arapahoe \nThermopolis, WY 82443-2783 \nPh. 307.864.3515 \nFax 307.864.3333 \nEmail: elections@hscounty.com \n76 North Main Street \nBuffalo, WY 82834-1883 \nPh. 307.684.7272 \nFax 307.684.2708 \nEmail: vedelman@johnsoncowy.us \n   clerk@johnsoncowy.us \nLaramie County Clerk \nLincoln County Clerk \nP.O. Box 608 \nCheyenne, WY 82003-0608 \nPh. 307.633.4242 \nFax 307.633.4240 \nEmail: election@laramiecountyclerk.com \n925 Sage Avenue, Suite 101 \nKemmerer, WY 83101 \nPh. 307.877.2027 or 2021 \nFax 307.877.3101 \nEmail: jpainter@lcwy.org \n             abrunski@lcwy.org \nNatrona County Clerk \nNiobrara County Clerk \n200 North Center Street \nP.O. Box 863 \nCasper, WY 82601-0863 \nPh. 307.235.9217 \nFax 307.235.9367 \nEmail: elections@natronacounty-wy.gov \nP.O. Box 420 \nLusk, WY 82225-0420 \nPh. 307.334.2211 \nFax 307.334.3013 \nEmail: bfreeman@niobraracounty.org \nPark County Clerk \nPlatte County Clerk \n1002 Sheridan \nCody, WY 82414-3589 \nPh. 307.527.8620 \nFax 307.527.8626 \nEmail: voterinfo@parkcounty.us \nP.O. Drawer 728 \nWheatland, WY 82201-0728 \nPh. 307.322.2315 \nFax 307.322.2245 \nEmail: pcelection@plattecountywyoming.com \n \nPage 3 of 3 \n \nSheridan County Clerk \nSublette County Clerk \n224 South Main Street; Suite B-17 \nSheridan, WY 82801 \nPh. 307.674.2515 \nFax 307.674.2909 \nEmail: elections@sheridancounty.com \nP.O. Box 250 \nPinedale, WY 82941-0250 \nPh. 307.367.4372 \nFax 307.367.6396 \nEmail: Carrie.Long@sublettewyo.com \nSweetwater County Clerk \nTeton County Clerk \n80 West Flaming Gorge Way, Suite 155 \nGreen River, WY 82935 \nPh. 307.872.3733 \nFax 307.872.3994 \nEmail: elections@sweet.wy.us \nP.O. Box 1727 \nJackson, WY 83001-1727 \nPh. 307.733.4430 \nFax 307.739.8681 \nEmail: elections@tetoncountywy.gov \nUinta County Clerk \nWashakie County Clerk \nP.O. Box 810 \nEvanston, WY 82931 \nPh. 307.783.0306 \nFax 307.783.0376 \nEmail: kigoble@uintacounty.com \n1001 Big Horn Avenue \nP.O. Box 260 \nWorland, WY 82401 \nPh. 307.347.3131 \nFax 307.347.9366 \nEmail: clerk@washakiecounty.net \n \nWeston County Clerk \n  \n1 West Main \nNewcastle, WY 82701 \nPh. 307.746.4744 \nFax 307.746.9505 \nEmail: clerk@westongov.com \n \n'

# %% [markdown]
# # Analyze the format of the text
#
# It looks like the fitz has extracted the tables in the PDF by row, and then by page, so that the county titles appear one after the other, and then the information for the those two counties one after the other.

# %%
print(raw_text)
# Out:
# Wyoming County Clerk’s Office
# Absentee Request and Updates to Voter Registration
# Contact Information
#
#
#
#
#
#
# Page 1 of 3
# Albany County Clerk
# Big Horn County Clerk
# 525 Grand Avenue, Suite 202
# Laramie, WY 82070
# Ph. 307.721.2546
# Fax 307.721.2544
# Email: elections@co.albany.wy.us
# County Courthouse, P.O. Box 31
# Basin, WY 82410-0031
# Ph. 307.568.2357
# Fax 307.568.9375
# Email: Lori.Smallwood@bighorncountywy.gov
#           annette.dillon@bighorncountywy.gov
# Campbell County Clerk
# Carbon County Clerk
# P.O. Box 3010
# Gillette, WY 82717-3010
# Ph. 307.686.1892
# Fax 307.687.6455
# Email: cds02@ccgov.net
# P.O. Box 6
# Rawlins, WY 82301-0006
# Ph. 307.328.2650
# Fax 307.328.2669
# Email: elections@carbonwy.com
# Converse County Clerk
# Crook County Clerk
# 107 North 5th Street, Suite 114
# Douglas, WY 82633-2448
# Ph. 307.358.2244
# Fax 307.358.5998
# Email:janeen.morvee@conversecountywy.gov
#
# P.O. Box 37
# Sundance, WY 82729-0037
# Ph. 307.283.1323
# Fax 307.283.3038
# Email: LindaF@crookcounty.wy.gov
#                melissaj@crookcounty.wy.gov
# Fremont County Clerk
# Goshen County Clerk
# 450 North 2nd Street, Room 220
# Lander, WY 82520-0090
# Ph. 307.332.1089
# Fax 307.332.1132
# Email: elections@fremontcountywy.gov
# P.O. Box 160
# Torrington, WY 82240-0160
# Ph. 307.532.4051
# Fax 307.532.7375
# Email: countyclerk@goshencounty.org
#
# Page 2 of 3
#
# Hot Springs County Clerk
# Johnson County Clerk
# 415 Arapahoe
# Thermopolis, WY 82443-2783
# Ph. 307.864.3515
# Fax 307.864.3333
# Email: elections@hscounty.com
# 76 North Main Street
# Buffalo, WY 82834-1883
# Ph. 307.684.7272
# Fax 307.684.2708
# Email: vedelman@johnsoncowy.us
#    clerk@johnsoncowy.us
# Laramie County Clerk
# Lincoln County Clerk
# P.O. Box 608
# Cheyenne, WY 82003-0608
# Ph. 307.633.4242
# Fax 307.633.4240
# Email: election@laramiecountyclerk.com
# 925 Sage Avenue, Suite 101
# Kemmerer, WY 83101
# Ph. 307.877.2027 or 2021
# Fax 307.877.3101
# Email: jpainter@lcwy.org
#              abrunski@lcwy.org
# Natrona County Clerk
# Niobrara County Clerk
# 200 North Center Street
# P.O. Box 863
# Casper, WY 82601-0863
# Ph. 307.235.9217
# Fax 307.235.9367
# Email: elections@natronacounty-wy.gov
# P.O. Box 420
# Lusk, WY 82225-0420
# Ph. 307.334.2211
# Fax 307.334.3013
# Email: bfreeman@niobraracounty.org
# Park County Clerk
# Platte County Clerk
# 1002 Sheridan
# Cody, WY 82414-3589
# Ph. 307.527.8620
# Fax 307.527.8626
# Email: voterinfo@parkcounty.us
# P.O. Drawer 728
# Wheatland, WY 82201-0728
# Ph. 307.322.2315
# Fax 307.322.2245
# Email: pcelection@plattecountywyoming.com
#
# Page 3 of 3
#
# Sheridan County Clerk
# Sublette County Clerk
# 224 South Main Street; Suite B-17
# Sheridan, WY 82801
# Ph. 307.674.2515
# Fax 307.674.2909
# Email: elections@sheridancounty.com
# P.O. Box 250
# Pinedale, WY 82941-0250
# Ph. 307.367.4372
# Fax 307.367.6396
# Email: Carrie.Long@sublettewyo.com
# Sweetwater County Clerk
# Teton County Clerk
# 80 West Flaming Gorge Way, Suite 155
# Green River, WY 82935
# Ph. 307.872.3733
# Fax 307.872.3994
# Email: elections@sweet.wy.us
# P.O. Box 1727
# Jackson, WY 83001-1727
# Ph. 307.733.4430
# Fax 307.739.8681
# Email: elections@tetoncountywy.gov
# Uinta County Clerk
# Washakie County Clerk
# P.O. Box 810
# Evanston, WY 82931
# Ph. 307.783.0306
# Fax 307.783.0376
# Email: kigoble@uintacounty.com
# 1001 Big Horn Avenue
# P.O. Box 260
# Worland, WY 82401
# Ph. 307.347.3131
# Fax 307.347.9366
# Email: clerk@washakiecounty.net
#
# Weston County Clerk
#
# 1 West Main
# Newcastle, WY 82701
# Ph. 307.746.4744
# Fax 307.746.9505
# Email: clerk@westongov.com

# %%
text_lines = []
for x in raw_text.splitlines():
    text_lines.append(x.strip())

# %%
[[x,y] for x,y in enumerate(text_lines)]
# Out:
# [[0, 'Wyoming County Clerk’s Office'],
#  [1, 'Absentee Request and Updates to Voter Registration'],
#  [2, 'Contact Information'],
#  [3, ''],
#  [4, ''],
#  [5, ''],
#  [6, ''],
#  [7, ''],
#  [8, ''],
#  [9, 'Page 1 of 3'],
#  [10, 'Albany County Clerk'],
#  [11, 'Big Horn County Clerk'],
#  [12, '525 Grand Avenue, Suite 202'],
#  [13, 'Laramie, WY 82070'],
#  [14, 'Ph. 307.721.2546'],
#  [15, 'Fax 307.721.2544'],
#  [16, 'Email: elections@co.albany.wy.us'],
#  [17, 'County Courthouse, P.O. Box 31'],
#  [18, 'Basin, WY 82410-0031'],
#  [19, 'Ph. 307.568.2357'],
#  [20, 'Fax 307.568.9375'],
#  [21, 'Email: Lori.Smallwood@bighorncountywy.gov'],
#  [22, 'annette.dillon@bighorncountywy.gov'],
#  [23, 'Campbell County Clerk'],
#  [24, 'Carbon County Clerk'],
#  [25, 'P.O. Box 3010'],
#  [26, 'Gillette, WY 82717-3010'],
#  [27, 'Ph. 307.686.1892'],
#  [28, 'Fax 307.687.6455'],
#  [29, 'Email: cds02@ccgov.net'],
#  [30, 'P.O. Box 6'],
#  [31, 'Rawlins, WY 82301-0006'],
#  [32, 'Ph. 307.328.2650'],
#  [33, 'Fax 307.328.2669'],
#  [34, 'Email: elections@carbonwy.com'],
#  [35, 'Converse County Clerk'],
#  [36, 'Crook County Clerk'],
#  [37, '107 North 5th Street, Suite 114'],
#  [38, 'Douglas, WY 82633-2448'],
#  [39, 'Ph. 307.358.2244'],
#  [40, 'Fax 307.358.5998'],
#  [41, 'Email:janeen.morvee@conversecountywy.gov'],
#  [42, ''],
#  [43, 'P.O. Box 37'],
#  [44, 'Sundance, WY 82729-0037'],
#  [45, 'Ph. 307.283.1323'],
#  [46, 'Fax 307.283.3038'],
#  [47, 'Email: LindaF@crookcounty.wy.gov'],
#  [48, 'melissaj@crookcounty.wy.gov'],
#  [49, 'Fremont County Clerk'],
#  [50, 'Goshen County Clerk'],
#  [51, '450 North 2nd Street, Room 220'],
#  [52, 'Lander, WY 82520-0090'],
#  [53, 'Ph. 307.332.1089'],
#  [54, 'Fax 307.332.1132'],
#  [55, 'Email: elections@fremontcountywy.gov'],
#  [56, 'P.O. Box 160'],
#  [57, 'Torrington, WY 82240-0160'],
#  [58, 'Ph. 307.532.4051'],
#  [59, 'Fax 307.532.7375'],
#  [60, 'Email: countyclerk@goshencounty.org'],
#  [61, ''],
#  [62, 'Page 2 of 3'],
#  [63, ''],
#  [64, 'Hot Springs County Clerk'],
#  [65, 'Johnson County Clerk'],
#  [66, '415 Arapahoe'],
#  [67, 'Thermopolis, WY 82443-2783'],
#  [68, 'Ph. 307.864.3515'],
#  [69, 'Fax 307.864.3333'],
#  [70, 'Email: elections@hscounty.com'],
#  [71, '76 North Main Street'],
#  [72, 'Buffalo, WY 82834-1883'],
#  [73, 'Ph. 307.684.7272'],
#  [74, 'Fax 307.684.2708'],
#  [75, 'Email: vedelman@johnsoncowy.us'],
#  [76, 'clerk@johnsoncowy.us'],
#  [77, 'Laramie County Clerk'],
#  [78, 'Lincoln County Clerk'],
#  [79, 'P.O. Box 608'],
#  [80, 'Cheyenne, WY 82003-0608'],
#  [81, 'Ph. 307.633.4242'],
#  [82, 'Fax 307.633.4240'],
#  [83, 'Email: election@laramiecountyclerk.com'],
#  [84, '925 Sage Avenue, Suite 101'],
#  [85, 'Kemmerer, WY 83101'],
#  [86, 'Ph. 307.877.2027 or 2021'],
#  [87, 'Fax 307.877.3101'],
#  [88, 'Email: jpainter@lcwy.org'],
#  [89, 'abrunski@lcwy.org'],
#  [90, 'Natrona County Clerk'],
#  [91, 'Niobrara County Clerk'],
#  [92, '200 North Center Street'],
#  [93, 'P.O. Box 863'],
#  [94, 'Casper, WY 82601-0863'],
#  [95, 'Ph. 307.235.9217'],
#  [96, 'Fax 307.235.9367'],
#  [97, 'Email: elections@natronacounty-wy.gov'],
#  [98, 'P.O. Box 420'],
#  [99, 'Lusk, WY 82225-0420'],
#  [100, 'Ph. 307.334.2211'],
#  [101, 'Fax 307.334.3013'],
#  [102, 'Email: bfreeman@niobraracounty.org'],
#  [103, 'Park County Clerk'],
#  [104, 'Platte County Clerk'],
#  [105, '1002 Sheridan'],
#  [106, 'Cody, WY 82414-3589'],
#  [107, 'Ph. 307.527.8620'],
#  [108, 'Fax 307.527.8626'],
#  [109, 'Email: voterinfo@parkcounty.us'],
#  [110, 'P.O. Drawer 728'],
#  [111, 'Wheatland, WY 82201-0728'],
#  [112, 'Ph. 307.322.2315'],
#  [113, 'Fax 307.322.2245'],
#  [114, 'Email: pcelection@plattecountywyoming.com'],
#  [115, ''],
#  [116, 'Page 3 of 3'],
#  [117, ''],
#  [118, 'Sheridan County Clerk'],
#  [119, 'Sublette County Clerk'],
#  [120, '224 South Main Street; Suite B-17'],
#  [121, 'Sheridan, WY 82801'],
#  [122, 'Ph. 307.674.2515'],
#  [123, 'Fax 307.674.2909'],
#  [124, 'Email: elections@sheridancounty.com'],
#  [125, 'P.O. Box 250'],
#  [126, 'Pinedale, WY 82941-0250'],
#  [127, 'Ph. 307.367.4372'],
#  [128, 'Fax 307.367.6396'],
#  [129, 'Email: Carrie.Long@sublettewyo.com'],
#  [130, 'Sweetwater County Clerk'],
#  [131, 'Teton County Clerk'],
#  [132, '80 West Flaming Gorge Way, Suite 155'],
#  [133, 'Green River, WY 82935'],
#  [134, 'Ph. 307.872.3733'],
#  [135, 'Fax 307.872.3994'],
#  [136, 'Email: elections@sweet.wy.us'],
#  [137, 'P.O. Box 1727'],
#  [138, 'Jackson, WY 83001-1727'],
#  [139, 'Ph. 307.733.4430'],
#  [140, 'Fax 307.739.8681'],
#  [141, 'Email: elections@tetoncountywy.gov'],
#  [142, 'Uinta County Clerk'],
#  [143, 'Washakie County Clerk'],
#  [144, 'P.O. Box 810'],
#  [145, 'Evanston, WY 82931'],
#  [146, 'Ph. 307.783.0306'],
#  [147, 'Fax 307.783.0376'],
#  [148, 'Email: kigoble@uintacounty.com'],
#  [149, '1001 Big Horn Avenue'],
#  [150, 'P.O. Box 260'],
#  [151, 'Worland, WY 82401'],
#  [152, 'Ph. 307.347.3131'],
#  [153, 'Fax 307.347.9366'],
#  [154, 'Email: clerk@washakiecounty.net'],
#  [155, ''],
#  [156, 'Weston County Clerk'],
#  [157, ''],
#  [158, '1 West Main'],
#  [159, 'Newcastle, WY 82701'],
#  [160, 'Ph. 307.746.4744'],
#  [161, 'Fax 307.746.9505'],
#  [162, 'Email: clerk@westongov.com'],
#  [163, '']]

# %% [markdown]
# # Extract the a list of the county clerks' names

# %%
counties = []
for row in raw_text.splitlines():
    if re.search(' Clerk ', row):
        county = row.strip()
        counties.append(county)

# %%
counties
# Out:
# ['Albany County Clerk',
#  'Big Horn County Clerk',
#  'Campbell County Clerk',
#  'Carbon County Clerk',
#  'Converse County Clerk',
#  'Crook County Clerk',
#  'Fremont County Clerk',
#  'Goshen County Clerk',
#  'Hot Springs County Clerk',
#  'Johnson County Clerk',
#  'Laramie County Clerk',
#  'Lincoln County Clerk',
#  'Natrona County Clerk',
#  'Niobrara County Clerk',
#  'Park County Clerk',
#  'Platte County Clerk',
#  'Sheridan County Clerk',
#  'Sublette County Clerk',
#  'Sweetwater County Clerk',
#  'Teton County Clerk',
#  'Uinta County Clerk',
#  'Washakie County Clerk',
#  'Weston County Clerk']

# %%
len(counties)
# Out:
# 23

# %% [markdown]
# # Break counties into two groups, those in the left column and those in the right

# %%
counties_1 = []
for row in range(0, len(counties), 2):
    counties_1.append(counties[row])

# %%
counties_2 = []
for row in range(1, len(counties), 2):
    counties_2.append(counties[row])

# %% [markdown]
# # Loop through the left column of addresses to build a dict

# %%
counties_1
# Out:
# ['Albany County Clerk',
#  'Campbell County Clerk',
#  'Converse County Clerk',
#  'Fremont County Clerk',
#  'Hot Springs County Clerk',
#  'Laramie County Clerk',
#  'Natrona County Clerk',
#  'Park County Clerk',
#  'Sheridan County Clerk',
#  'Sweetwater County Clerk',
#  'Uinta County Clerk',
#  'Weston County Clerk']

# %%
data_1 = []
for num,row in enumerate(text_lines):
    if row in set(counties_1):
        if row=='Natrona County Clerk':
            state = 'Nebraska'
            county = row
            print(num, row)
            location_type = np.nan
            name = np.nan
            address_1 = text_lines[num+2]
            address_2 = text_lines[num+3]
            city = text_lines[num+4].split(', ')[0]
            zip_code = text_lines[num+4].split(', WY ')[1]
            phone = text_lines[num+5].split('Ph. ')[1]
            county_website_url = np.nan
            validate_url = np.nan
            email = text_lines[num+7]
            fax = text_lines[num+6].split('Fax ')[1]            
        else:
            state = 'Nebraska'
            county = row
            print(num, row)
            location_type = np.nan
            name = np.nan
            address_1 = text_lines[num+2]
            address_2 = np.nan
            city = text_lines[num+3].split(', ')[0]
            zip_code = text_lines[num+3].split(', WY ')[1]
            phone = text_lines[num+4].split('Ph. ')[1]
            county_website_url = np.nan
            validate_url = np.nan
            email = text_lines[num+6]
            fax = text_lines[num+5].split('Fax ')[1]
        
        data = {'state': state, 'county': county, 'location_type': location_type, 'name': name, 'address_1': address_1,
               'address_2': address_2, 'city': city, 'zip_code': zip_code, 'phone': phone, 'county_website_url':county_website_url,
               'validate_url': validate_url, 'email':email, 'fax':fax}
        
        data_1.append(data)
# Out:
# 10 Albany County Clerk
# 23 Campbell County Clerk
# 35 Converse County Clerk
# 49 Fremont County Clerk
# 64 Hot Springs County Clerk
# 77 Laramie County Clerk
# 90 Natrona County Clerk
# 103 Park County Clerk
# 118 Sheridan County Clerk
# 130 Sweetwater County Clerk
# 142 Uinta County Clerk
# 156 Weston County Clerk

# %%
data_1
# Out:
# [{'state': 'Nebraska',
#   'county': 'Albany County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': '525 Grand Avenue, Suite 202',
#   'address_2': nan,
#   'city': 'Laramie',
#   'zip_code': '82070',
#   'phone': '307.721.2546',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: elections@co.albany.wy.us',
#   'fax': '307.721.2544'},
#  {'state': 'Nebraska',
#   'county': 'Campbell County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': 'P.O. Box 3010',
#   'address_2': nan,
#   'city': 'Gillette',
#   'zip_code': '82717-3010',
#   'phone': '307.686.1892',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: cds02@ccgov.net',
#   'fax': '307.687.6455'},
#  {'state': 'Nebraska',
#   'county': 'Converse County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': '107 North 5th Street, Suite 114',
#   'address_2': nan,
#   'city': 'Douglas',
#   'zip_code': '82633-2448',
#   'phone': '307.358.2244',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email:janeen.morvee@conversecountywy.gov',
#   'fax': '307.358.5998'},
#  {'state': 'Nebraska',
#   'county': 'Fremont County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': '450 North 2nd Street, Room 220',
#   'address_2': nan,
#   'city': 'Lander',
#   'zip_code': '82520-0090',
#   'phone': '307.332.1089',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: elections@fremontcountywy.gov',
#   'fax': '307.332.1132'},
#  {'state': 'Nebraska',
#   'county': 'Hot Springs County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': '415 Arapahoe',
#   'address_2': nan,
#   'city': 'Thermopolis',
#   'zip_code': '82443-2783',
#   'phone': '307.864.3515',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: elections@hscounty.com',
#   'fax': '307.864.3333'},
#  {'state': 'Nebraska',
#   'county': 'Laramie County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': 'P.O. Box 608',
#   'address_2': nan,
#   'city': 'Cheyenne',
#   'zip_code': '82003-0608',
#   'phone': '307.633.4242',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: election@laramiecountyclerk.com',
#   'fax': '307.633.4240'},
#  {'state': 'Nebraska',
#   'county': 'Natrona County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': '200 North Center Street',
#   'address_2': 'P.O. Box 863',
#   'city': 'Casper',
#   'zip_code': '82601-0863',
#   'phone': '307.235.9217',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: elections@natronacounty-wy.gov',
#   'fax': '307.235.9367'},
#  {'state': 'Nebraska',
#   'county': 'Park County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': '1002 Sheridan',
#   'address_2': nan,
#   'city': 'Cody',
#   'zip_code': '82414-3589',
#   'phone': '307.527.8620',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: voterinfo@parkcounty.us',
#   'fax': '307.527.8626'},
#  {'state': 'Nebraska',
#   'county': 'Sheridan County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': '224 South Main Street; Suite B-17',
#   'address_2': nan,
#   'city': 'Sheridan',
#   'zip_code': '82801',
#   'phone': '307.674.2515',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: elections@sheridancounty.com',
#   'fax': '307.674.2909'},
#  {'state': 'Nebraska',
#   'county': 'Sweetwater County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': '80 West Flaming Gorge Way, Suite 155',
#   'address_2': nan,
#   'city': 'Green River',
#   'zip_code': '82935',
#   'phone': '307.872.3733',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: elections@sweet.wy.us',
#   'fax': '307.872.3994'},
#  {'state': 'Nebraska',
#   'county': 'Uinta County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': 'P.O. Box 810',
#   'address_2': nan,
#   'city': 'Evanston',
#   'zip_code': '82931',
#   'phone': '307.783.0306',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: kigoble@uintacounty.com',
#   'fax': '307.783.0376'},
#  {'state': 'Nebraska',
#   'county': 'Weston County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': '1 West Main',
#   'address_2': nan,
#   'city': 'Newcastle',
#   'zip_code': '82701',
#   'phone': '307.746.4744',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: clerk@westongov.com',
#   'fax': '307.746.9505'}]

# %% [markdown]
# # Loop through the right column of address to build a dict
#
# Some counties have two emails listed. Adust the row reference to account for the extra row.

# %%
counties_2
# Out:
# ['Big Horn County Clerk',
#  'Carbon County Clerk',
#  'Crook County Clerk',
#  'Goshen County Clerk',
#  'Johnson County Clerk',
#  'Lincoln County Clerk',
#  'Niobrara County Clerk',
#  'Platte County Clerk',
#  'Sublette County Clerk',
#  'Teton County Clerk',
#  'Washakie County Clerk']

# %%
data_2 = []
for num,row in enumerate(text_lines):
    if row in set(counties_2):
        if row=='Crook County Clerk' or row=='Niobrara County Clerk':
            print(row)
            state = 'Nebraska'
            county = row
            location_type = np.nan
            name = np.nan
            address_1 = text_lines[num+7]
            address_2 = np.nan
            city = text_lines[num+8].split(', ')[0]
            zip_code = text_lines[num+8].split(', WY ')[1]
            phone = text_lines[num+9].split('Ph. ')[1]
            county_website_url = np.nan
            validate_url = np.nan
            email = text_lines[num+11]
            fax = text_lines[num+10].split('Fax ')[1]            
        elif row=='Washakie County Clerk':
            print(row)
            state = 'Nebraska'
            county = row
            location_type = np.nan
            name = np.nan
            address_1 = text_lines[num+6]
            address_2 = text_lines[num+7]
            city = text_lines[num+8].split(', ')[0]
            zip_code = text_lines[num+8].split(', WY ')[1]
            phone = text_lines[num+9].split('Ph. ')[1]
            county_website_url = np.nan
            validate_url = np.nan
            email = text_lines[num+11]
            fax = text_lines[num+10].split('Fax ')[1]  
        else:
            state = 'Nebraska'
            county = row
            print(row)
            location_type = np.nan
            name = np.nan
            address_1 = text_lines[num+6]
            address_2 = np.nan
            city = text_lines[num+7].split(', ')[0]
            zip_code = text_lines[num+7].split(', WY ')[1]
            phone = text_lines[num+8].split('Ph. ')[1]
            county_website_url = np.nan
            validate_url = np.nan
            email = text_lines[num+10]
            fax = text_lines[num+9].split('Fax ')[1]
        
        data = {'state': state, 'county': county, 'location_type': location_type, 'name': name, 'address_1': address_1,
               'address_2': address_2, 'city': city, 'zip_code': zip_code, 'phone': phone, 'county_website_url':county_website_url,
               'validate_url': validate_url, 'email':email, 'fax':fax}
        
        data_2.append(data)
# Out:
# Big Horn County Clerk
# Carbon County Clerk
# Crook County Clerk
# Goshen County Clerk
# Johnson County Clerk
# Lincoln County Clerk
# Niobrara County Clerk
# Platte County Clerk
# Sublette County Clerk
# Teton County Clerk
# Washakie County Clerk

# %%
data_2
# Out:
# [{'state': 'Nebraska',
#   'county': 'Big Horn County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': 'County Courthouse, P.O. Box 31',
#   'address_2': nan,
#   'city': 'Basin',
#   'zip_code': '82410-0031',
#   'phone': '307.568.2357',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: Lori.Smallwood@bighorncountywy.gov',
#   'fax': '307.568.9375'},
#  {'state': 'Nebraska',
#   'county': 'Carbon County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': 'P.O. Box 6',
#   'address_2': nan,
#   'city': 'Rawlins',
#   'zip_code': '82301-0006',
#   'phone': '307.328.2650',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: elections@carbonwy.com',
#   'fax': '307.328.2669'},
#  {'state': 'Nebraska',
#   'county': 'Crook County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': 'P.O. Box 37',
#   'address_2': nan,
#   'city': 'Sundance',
#   'zip_code': '82729-0037',
#   'phone': '307.283.1323',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: LindaF@crookcounty.wy.gov',
#   'fax': '307.283.3038'},
#  {'state': 'Nebraska',
#   'county': 'Goshen County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': 'P.O. Box 160',
#   'address_2': nan,
#   'city': 'Torrington',
#   'zip_code': '82240-0160',
#   'phone': '307.532.4051',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: countyclerk@goshencounty.org',
#   'fax': '307.532.7375'},
#  {'state': 'Nebraska',
#   'county': 'Johnson County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': '76 North Main Street',
#   'address_2': nan,
#   'city': 'Buffalo',
#   'zip_code': '82834-1883',
#   'phone': '307.684.7272',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: vedelman@johnsoncowy.us',
#   'fax': '307.684.2708'},
#  {'state': 'Nebraska',
#   'county': 'Lincoln County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': '925 Sage Avenue, Suite 101',
#   'address_2': nan,
#   'city': 'Kemmerer',
#   'zip_code': '83101',
#   'phone': '307.877.2027 or 2021',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: jpainter@lcwy.org',
#   'fax': '307.877.3101'},
#  {'state': 'Nebraska',
#   'county': 'Niobrara County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': 'P.O. Box 420',
#   'address_2': nan,
#   'city': 'Lusk',
#   'zip_code': '82225-0420',
#   'phone': '307.334.2211',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: bfreeman@niobraracounty.org',
#   'fax': '307.334.3013'},
#  {'state': 'Nebraska',
#   'county': 'Platte County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': 'P.O. Drawer 728',
#   'address_2': nan,
#   'city': 'Wheatland',
#   'zip_code': '82201-0728',
#   'phone': '307.322.2315',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: pcelection@plattecountywyoming.com',
#   'fax': '307.322.2245'},
#  {'state': 'Nebraska',
#   'county': 'Sublette County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': 'P.O. Box 250',
#   'address_2': nan,
#   'city': 'Pinedale',
#   'zip_code': '82941-0250',
#   'phone': '307.367.4372',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: Carrie.Long@sublettewyo.com',
#   'fax': '307.367.6396'},
#  {'state': 'Nebraska',
#   'county': 'Teton County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': 'P.O. Box 1727',
#   'address_2': nan,
#   'city': 'Jackson',
#   'zip_code': '83001-1727',
#   'phone': '307.733.4430',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: elections@tetoncountywy.gov',
#   'fax': '307.739.8681'},
#  {'state': 'Nebraska',
#   'county': 'Washakie County Clerk',
#   'location_type': nan,
#   'name': nan,
#   'address_1': '1001 Big Horn Avenue',
#   'address_2': 'P.O. Box 260',
#   'city': 'Worland',
#   'zip_code': '82401',
#   'phone': '307.347.3131',
#   'county_website_url': nan,
#   'validate_url': nan,
#   'email': 'Email: clerk@washakiecounty.net',
#   'fax': '307.347.9366'}]

# %% [markdown]
# # Create DataFrame of data

# %%
data_1 = pd.DataFrame(data_1)

# %%
data_2 = pd.DataFrame(data_2)

# %%
data_df = pd.concat([data_1, data_2]).sort_values(by='county', ignore_index=True)

# %%
data_df
# Out:
#        state                    county  location_type  name  \
# 0   Nebraska       Albany County Clerk            NaN   NaN
# 1   Nebraska     Big Horn County Clerk            NaN   NaN
# 2   Nebraska     Campbell County Clerk            NaN   NaN
# 3   Nebraska       Carbon County Clerk            NaN   NaN
# 4   Nebraska     Converse County Clerk            NaN   NaN
# 5   Nebraska        Crook County Clerk            NaN   NaN
# 6   Nebraska      Fremont County Clerk            NaN   NaN
# 7   Nebraska       Goshen County Clerk            NaN   NaN
# 8   Nebraska  Hot Springs County Clerk            NaN   NaN
# 9   Nebraska      Johnson County Clerk            NaN   NaN
# 10  Nebraska      Laramie County Clerk            NaN   NaN
# 11  Nebraska      Lincoln County Clerk            NaN   NaN
# 12  Nebraska      Natrona County Clerk            NaN   NaN
# 13  Nebraska     Niobrara County Clerk            NaN   NaN
# 14  Nebraska         Park County Clerk            NaN   NaN
# 15  Nebraska       Platte County Clerk            NaN   NaN
# 16  Nebraska     Sheridan County Clerk            NaN   NaN
# 17  Nebraska     Sublette County Clerk            NaN   NaN
# 18  Nebraska   Sweetwater County Clerk            NaN   NaN
# 19  Nebraska        Teton County Clerk            NaN   NaN
# 20  Nebraska        Uinta County Clerk            NaN   NaN
# 21  Nebraska     Washakie County Clerk            NaN   NaN
# 22  Nebraska       Weston County Clerk            NaN   NaN
#
#                                address_1     address_2         city  \
# 0            525 Grand Avenue, Suite 202           NaN      Laramie
# 1         County Courthouse, P.O. Box 31           NaN        Basin
# 2                          P.O. Box 3010           NaN     Gillette
# 3                             P.O. Box 6           NaN      Rawlins
# 4        107 North 5th Street, Suite 114           NaN      Douglas
# 5                            P.O. Box 37           NaN     Sundance
# 6         450 North 2nd Street, Room 220           NaN       Lander
# 7                           P.O. Box 160           NaN   Torrington
# 8                           415 Arapahoe           NaN  Thermopolis
# 9                   76 North Main Street           NaN      Buffalo
# 10                          P.O. Box 608           NaN     Cheyenne
# 11            925 Sage Avenue, Suite 101           NaN     Kemmerer
# 12               200 North Center Street  P.O. Box 863       Casper
# 13                          P.O. Box 420           NaN         Lusk
# 14                         1002 Sheridan           NaN         Cody
# 15                       P.O. Drawer 728           NaN    Wheatland
# 16     224 South Main Street; Suite B-17           NaN     Sheridan
# 17                          P.O. Box 250           NaN     Pinedale
# 18  80 West Flaming Gorge Way, Suite 155           NaN  Green River
# 19                         P.O. Box 1727           NaN      Jackson
# 20                          P.O. Box 810           NaN     Evanston
# 21                  1001 Big Horn Avenue  P.O. Box 260      Worland
# 22                           1 West Main           NaN    Newcastle
#
#       zip_code                 phone  county_website_url  validate_url  \
# 0        82070          307.721.2546                 NaN           NaN
# 1   82410-0031          307.568.2357                 NaN           NaN
# 2   82717-3010          307.686.1892                 NaN           NaN
# 3   82301-0006          307.328.2650                 NaN           NaN
# 4   82633-2448          307.358.2244                 NaN           NaN
# 5   82729-0037          307.283.1323                 NaN           NaN
# 6   82520-0090          307.332.1089                 NaN           NaN
# 7   82240-0160          307.532.4051                 NaN           NaN
# 8   82443-2783          307.864.3515                 NaN           NaN
# 9   82834-1883          307.684.7272                 NaN           NaN
# 10  82003-0608          307.633.4242                 NaN           NaN
# 11       83101  307.877.2027 or 2021                 NaN           NaN
# 12  82601-0863          307.235.9217                 NaN           NaN
# 13  82225-0420          307.334.2211                 NaN           NaN
# 14  82414-3589          307.527.8620                 NaN           NaN
# 15  82201-0728          307.322.2315                 NaN           NaN
# 16       82801          307.674.2515                 NaN           NaN
# 17  82941-0250          307.367.4372                 NaN           NaN
# 18       82935          307.872.3733                 NaN           NaN
# 19  83001-1727          307.733.4430                 NaN           NaN
# 20       82931          307.783.0306                 NaN           NaN
# 21       82401          307.347.3131                 NaN           NaN
# 22       82701          307.746.4744                 NaN           NaN
#
#                                         email           fax
# 0            Email: elections@co.albany.wy.us  307.721.2544
# 1   Email: Lori.Smallwood@bighorncountywy.gov  307.568.9375
# 2                      Email: cds02@ccgov.net  307.687.6455
# 3               Email: elections@carbonwy.com  307.328.2669
# 4    Email:janeen.morvee@conversecountywy.gov  307.358.5998
# 5            Email: LindaF@crookcounty.wy.gov  307.283.3038
# 6        Email: elections@fremontcountywy.gov  307.332.1132
# 7         Email: countyclerk@goshencounty.org  307.532.7375
# 8               Email: elections@hscounty.com  307.864.3333
# 9              Email: vedelman@johnsoncowy.us  307.684.2708
# 10     Email: election@laramiecountyclerk.com  307.633.4240
# 11                   Email: jpainter@lcwy.org  307.877.3101
# 12      Email: elections@natronacounty-wy.gov  307.235.9367
# 13         Email: bfreeman@niobraracounty.org  307.334.3013
# 14             Email: voterinfo@parkcounty.us  307.527.8626
# 15  Email: pcelection@plattecountywyoming.com  307.322.2245
# 16        Email: elections@sheridancounty.com  307.674.2909
# 17         Email: Carrie.Long@sublettewyo.com  307.367.6396
# 18               Email: elections@sweet.wy.us  307.872.3994
# 19         Email: elections@tetoncountywy.gov  307.739.8681
# 20             Email: kigoble@uintacounty.com  307.783.0376
# 21            Email: clerk@washakiecounty.net  307.347.9366
# 22                 Email: clerk@westongov.com  307.746.9505

# %% [markdown]
# # Remove email tag from field

# %%
data_df['email'] = data_df['email'].apply(lambda x: x.split('Email:')[1].strip())

# %% [markdown]
# # Write DataFrame to csv

# %%
data_df.to_csv('Wyoming.csv')
